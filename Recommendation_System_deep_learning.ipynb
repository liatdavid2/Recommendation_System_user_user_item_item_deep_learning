# %% [markdown]
# #Understand and order data

# %% [markdown]
# #Understand and order data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# We'll train a network that learns to predict a movie based on the outgoing links on the corresponding Wikipedia page. 
# This creates embeddings for the movies. This in turn lets us recommend movies based on other movies - similar movies are next to each other in the embedding space.
import json
from collections import Counter
from keras.models import Model
from keras.layers import Embedding, Input, Reshape
from keras.layers.merge import Dot
from sklearn.linear_model import LinearRegression
import numpy as np
import random
from sklearn import svm

# %%
# Load our dataset - wikipedia movies links
with open('/content/gdrive/MyDrive/ml/RecommendationSystem/wp_movies_10k.ndjson') as fin:
    movies = [json.loads(l) for l in fin]

# %%
# Examining our dataset
print('type: ',type(movies))
movies[0]
# Out:
# type:  <class 'list'>
# ['Deadpool (film)',
#  {'Software Used': 'Adobe Premier Pro',
#   'alt': "Official poster shows the titular hero Deadpool standing in front of the viewers, with hugging his hands, and donning his traditional black and red suit and mask, and the film's name, credits and billing below him.",
#   'budget': '$58 million',
#   'caption': 'Theatrical release poster',
#   'cinematography': 'Ken Seng',
#   'country': 'United States',
#   'director': 'Tim Miller',
#   'distributor': '20th Century Fox',
#   'editing': 'Julian Clarke',
#   'gross': '$783.1 million',
#   'image': 'Deadpool poster.jpg',
#   'language': 'English',
#   'music': 'Tom Holkenborg',
#   'name': 'Deadpool',
#   'runtime': '108 minutes'},
#  ['Tim Miller (director)',
#   'Simon Kinberg',
#   'Ryan Reynolds',
#   'Lauren Shuler Donner',
#   'Rhett Reese',
#   'Paul Wernick',
#   'Deadpool',
#   'Fabian Nicieza',
#   'Rob Liefeld',
#   'Morena Baccarin',
#   'Ed Skrein',
#   'T.J. Miller',
#   'Gina Carano',
#   'Leslie Uggams',
#   'Brianna Hildebrand',
#   'Stefan Kapičić',
#   'Junkie XL',
#   'Julian Clarke',
#   'Marvel Entertainment',
#   'Kinberg Genre',
#   'Lauren Shuler Donner',
#   'TSG Entertainment',
#   '20th Century Fox',
#   'Le Grand Rex',
#   'Variety (magazine)',
#   'Box Office Mojo',
#   'superhero film',
#   'Tim Miller (director)',
#   'Rhett Reese',
#   'Paul Wernick',
#   'Marvel Comics',
#   'Deadpool',
#   'X-Men (film series)',
#   'Ryan Reynolds',
#   'Morena Baccarin',
#   'Ed Skrein',
#   'T.J. Miller',
#   'Gina Carano',
#   'Leslie Uggams',
#   'Brianna Hildebrand',
#   'Stefan Kapičić',
#   'antihero',
#   'New Line Cinema',
#   '20th Century Fox',
#   'X-Men Origins: Wolverine',
#   'principal photography',
#   'Vancouver',
#   'IMAX',
#   'Digital Light Processing',
#   'D-Box Technologies',
#   'List of accolades received by Deadpool (film)',
#   'Golden Globe Award',
#   'Golden Globe Award for Best Motion Picture – Musical or Comedy',
#   'Golden Globe Award for Best Actor – Motion Picture Musical or Comedy',
#   'Producers Guild of America Award',
#   "Critics' Choice Movie Awards",
#   "Critics' Choice Movie Award for Best Comedy",
#   "Critics' Choice Movie Award for Best Actor in a Comedy",
#   '2016 in film',
#   '#Sequels',
#   'nonlinear narrative',
#   'Deadpool',
#   'special forces',
#   'Copycat (Marvel Comics)',
#   'Liver cancer',
#   'Lung cancer',
#   'Prostate cancer',
#   'Brain tumor',
#   'Ajax (comics)#Deadpool character',
#   'Angel Dust (comics)',
#   'healing factor',
#   'rebar',
#   'Weasel (Marvel Comics)',
#   'Blind Al',
#   'Colossus (comics)',
#   'Negasonic Teenage Warhead',
#   'X-Men',
#   'helicarrier',
#   'post-credits scene',
#   'Cable (comics)',
#   'File:Cast of Deadpool.jpg',
#   'San Diego Comic-Con',
#   'Ryan Reynolds',
#   'Deadpool',
#   'cancer',
#   'X-Men Origins: Wolverine',
#   'fourth wall',
#   'Morena Baccarin',
#   'Copycat (Marvel Comics)',
#   'damsel in distress',
#   'Ed Skrein',
#   'Ajax (comics)#Deadpool character',
#   'Weapon X',
#   'YouTube',
#   'Tim Miller (director)',
#   'T.J. Miller',
#   'Weasel (Marvel Comics)',
#   'Simon Kinberg',
#   'USA Today',
#   'Gina Carano',
#   'Angel Dust (comics)',
#   'Leslie Uggams',
#   'Blind Al',
#   'Indiewire',
#   'Brianna Hildebrand',
#   'Negasonic Teenage Warhead',
#   'X-Men',
#   'Marvel Studios',
#   'Kevin Feige',
#   'Ego the Living Planet',
#   'Guardians of the Galaxy Vol. 2',
#   'Stefan Kapičić',
#   'Colossus (comics)',
#   'Daniel Cudmore',
#   'X2 (film)',
#   'X-Men: The Last Stand',
#   'X-Men: Days of Future Past',
#   'Andre Tricoteux',
#   'Karan Soni',
#   'Jed Rees',
#   'Agent Smith',
#   'Stan Lee',
#   'Rob Liefeld',
#   'Isaac C. Singleton Jr.',
#   'Bob, Agent of Hydra',
#   'Hydra (comics)',
#   'Nathan Fillion',
#   'Twitter',
#   'Simon Kinberg',
#   'Artisan Entertainment',
#   'Marvel Entertainment',
#   'Deadpool',
#   'New Line Cinema',
#   'David S. Goyer',
#   'Ryan Reynolds',
#   'Shar Pei',
#   'Cable & Deadpool',
#   'Turnaround (filmmaking)',
#   'X-Men Origins: Wolverine',
#   'Lauren Shuler Donner',
#   'Reboot (fiction)',
#   'fourth wall',
#   'Rhett Reese',
#   'Paul Wernick',
#   'Robert Rodriguez',
#   'Tim Miller (director)',
#   'Adam Berg (director)',
#   'Blur Studio',
#   'James Cameron',
#   'David Fincher',
#   'development hell',
#   'Garrison Kane',
#   'Cannonball (comics)',
#   'Computer-generated imagery',
#   'Hillbilly',
#   'Wyre (comics)',
#   'Angel Dust (comics)',
#   'Cable (comics)',
#   'List of directorial debuts',
#   'Colossus (comics)',
#   'Simon Kinberg',
#   'The Hollywood Reporter',
#   'T. J. Miller',
#   'Ed Skrein',
#   'Gina Carano',
#   'Angel Dust (comics)',
#   'Morena Baccarin',
#   'Taylor Schilling',
#   'Crystal Reed',
#   'Rebecca Rittenhouse',
#   'Sarah Greene (actress)',
#   'Jessica De Gouw',
#   'Weasel (Marvel Comics)',
#   'Copycat (Marvel Comics)',
#   'Brianna Hildebrand',
#   'Negasonic Teenage Warhead',
#   'Ajax (comics)#Deadpool character',
#   'Leslie Uggams',
#   'Blind Al',
#   'Jed Rees',
#   'Stefan Kapičić',
#   'Colossus (comics)',
#   'Daniel Cudmore',
#   'Twitter',
#   'File:Deadpool, Georgia Viaduct, Vancouver, April 6 2015 - 3.jpg',
#   'Rolling Stone',
#   'Principal photography',
#   'Vancouver',
#   'stunt coordinator',
#   'CBC News',
#   'David Cronenberg',
#   'Eastern Promises',
#   'Yahoo! Movies',
#   'Digital Domain',
#   'Weta Digital',
#   'Rodeo FX',
#   'Luma Pictures',
#   'Image Engine',
#   'Adobe Systems',
#   'matte paintings',
#   'helicarrier',
#   'Detroit',
#   'Chicago',
#   'File:Colossus - mocap.jpg',
#   'Colossus (comics)',
#   'Computer-generated imagery',
#   'Digital Domain',
#   'Cold-formed steel',
#   'Hot working',
#   'Taxicab',
#   'Junkie XL',
#   'ARP 2600',
#   'Synclavier',
#   'Oberheim Electronics#Oberheim polyphonic synthesizers',
#   'io9',
#   'YouTube personality',
#   'Deadpool (video game)',
#   'Milan Records',
#   'Grand Rex',
#   'IMAX',
#   'Digital Light Processing',
#   'D-Box Technologies',
#   'The Hollywood Reporter',
#   'Uzbekistan',
#   'Central Board of Film Certification',
#   'The Hollywood Reporter',
#   'Hong Kong',
#   'Singapore',
#   'standing ovation',
#   'The Hollywood Reporter',
#   'Meta-joke',
#   'Business Insider',
#   'viral marketing',
#   'Christmas',
#   "Valentine's Day",
#   'io9',
#   'emoji',
#   'YouTube',
#   'Screen Junkies',
#   'The Guardian',
#   'Blu-ray',
#   '2016 in film',
#   'The Matrix Reloaded',
#   'Forbes',
#   'Variety (magazine)',
#   'X-Men: Days of Future Past',
#   'Deadline.com',
#   'James Cameron',
#   'George Lucas',
#   'Star Wars: Episode III – Revenge of the Sith',
#   'The Dark Knight Rises',
#   'The Hollywood Reporter',
#   'IMAX',
#   '3D film',
#   'Los Angeles Times',
#   'Yahoo!',
#   'Variety (magazine)',
#   'Forbes (magazine)',
#   "Presidents' Day (United States)",
#   'Zoolander 2',
#   'How to Be Single',
#   'The Hollywood Reporter',
#   'Deadline.com',
#   'Variety (magazine)',
#   'Guardians of the Galaxy (film)',
#   'Captain America: The Winter Soldier',
#   'The Hollywood Reporter',
#   'Deadline.com',
#   'R-rated',
#   'The Hangover Part II',
#   'Fifty Shades of Grey (film)',
#   'The Hollywood Reporter',
#   'Deadline.com',
#   'word of mouth',
#   'Star Wars: Episode III – Revenge of the Sith',
#   'Forbes',
#   'Century Theatres',
#   'Deadline.com',
#   'The Hollywood Reporter',
#   'The Avengers (2012 film)',
#   'The Hunger Games (film)',
#   'Forbes (magazine)',
#   'Furious 7',
#   'Alice in Wonderland (2010 film)',
#   'Wanted (2008 film)',
#   'Watchmen (film)',
#   'The Vow (2012 film)',
#   'X-Men (film)',
#   'X-Men: First Class',
#   'The Wolverine (film)',
#   'X-Men Origins: Wolverine',
#   'Deadline.com',
#   'Second weekend in box office performance',
#   'Avengers: Age of Ultron',
#   'X-Men: The Last Stand',
#   '300 (film)',
#   'Forbes',
#   'The Passion of the Christ',
#   'Forbes',
#   'Zootopia',
#   'London Has Fallen',
#   'Non-Hispanic whites',
#   'Hispanic',
#   'African-American',
#   'Asian Americans',
#   'Guardians of the Galaxy (film)',
#   'Captain America: Civil War',
#   'Avengers: Age of Ultron',
#   'Batman v Superman: Dawn of Justice',
#   'Suicide Squad (film)',
#   'The Hollywood Reporter',
#   'Spectre (2015)',
#   'United Kingdom and Ireland',
#   'Chinese New Year',
#   'Hong Kong',
#   'Singapore',
#   'The Mermaid (2016 film)',
#   'Deadline.com',
#   'Ip Man 3',
#   'Zootopia',
#   'Iron Man 3',
#   'Star Wars: The Force Awakens',
#   'Rotten Tomatoes',
#   'Rotten Tomatoes',
#   'Metacritic',
#   'CinemaScore',
#   'Peter Travers',
#   'Rolling Stone',
#   'Rolling Stone',
#   'TheWrap',
#   'Alonso Duralde',
#   'Guardians of the Galaxy (film)',
#   'Christy Lemire',
#   'Richard Roeper',
#   'Chicago Sun-Times',
#   'Kenneth Turan',
#   'Los Angeles Times',
#   'Los Angeles Times',
#   'The Hollywood Reporter',
#   'Deadline.com',
#   'Spider-Man',
#   'Superhero Hype',
#   '/Film',
#   'Domino (comics)',
#   'TheWrap',
#   'Mashable',
#   'David Leitch (filmmaker)',
#   'Rupert Sanders',
#   'Drew Goddard',
#   'Mashable',
#   'X-Force',
#   'Hugh Jackman',
#   'Twitter',
#   'Variety (magazine)',
#   'The Hollywood Reporter',
#   'British Board of Film Classification',
#   'Los Angeles Times',
#   'Variety (magazine)',
#   'MTV News',
#   'Empire (film magazine)',
#   'The Hollywood Reporter',
#   'Variety (magazine)',
#   'The Daily Dot',
#   'Bleeding Cool',
#   'The Hollywood Reporter',
#   'TheWrap',
#   'The Hollywood Reporter',
#   'Variety (magazine)',
#   'Entertainment Weekly',
#   'Deadline.com',
#   'MTV News',
#   'Deadline.com',
#   'Business Insider',
#   'The Hollywood Reporter',
#   'Twitter',
#   'Empire (magazine)',
#   'fxguide',
#   'Category:20th Century Fox films',
#   'Category:2010s action films',
#   'Category:2010s comedy films',
#   'Category:2010s superhero films',
#   'Category:2016 films',
#   'Category:American action comedy films',
#   'Category:American black comedy films',
#   'Category:American films',
#   'Category:Deadpool',
#   'Category:Directorial debut films',
#   'Category:English-language films',
#   'Category:Film scores by Junkie XL',
#   'Category:Film spin-offs',
#   'Category:Films about cancer',
#   'Category:Films about revenge',
#   'Category:Films directed by Tim Miller',
#   'Category:Films set in New York',
#   'Category:Films shot in Vancouver',
#   'Category:Films with live action and animation',
#   'Category:Human experimentation in fiction',
#   'Category:IMAX films',
#   'Category:Metafictional works',
#   'Category:Nonlinear narrative films',
#   'Category:Performance capture in film',
#   'Category:Self-reflexive films',
#   'Category:Superhero comedy films',
#   'Category:Vigilante films',
#   'Category:X-Men films'],
#  '84%',
#  '6.9/10']

# %%
# movie name
movies[0][0]
# Out:
# 'Deadpool (film)'

# %%
# movie metadata
movies[0][1]
# Out:
# {'Software Used': 'Adobe Premier Pro',
#  'alt': "Official poster shows the titular hero Deadpool standing in front of the viewers, with hugging his hands, and donning his traditional black and red suit and mask, and the film's name, credits and billing below him.",
#  'budget': '$58 million',
#  'caption': 'Theatrical release poster',
#  'cinematography': 'Ken Seng',
#  'country': 'United States',
#  'director': 'Tim Miller',
#  'distributor': '20th Century Fox',
#  'editing': 'Julian Clarke',
#  'gross': '$783.1 million',
#  'image': 'Deadpool poster.jpg',
#  'language': 'English',
#  'music': 'Tom Holkenborg',
#  'name': 'Deadpool',
#  'runtime': '108 minutes'}

# %%
# movie links
movies[0][2]
# Out:
# ['Tim Miller (director)',
#  'Simon Kinberg',
#  'Ryan Reynolds',
#  'Lauren Shuler Donner',
#  'Rhett Reese',
#  'Paul Wernick',
#  'Deadpool',
#  'Fabian Nicieza',
#  'Rob Liefeld',
#  'Morena Baccarin',
#  'Ed Skrein',
#  'T.J. Miller',
#  'Gina Carano',
#  'Leslie Uggams',
#  'Brianna Hildebrand',
#  'Stefan Kapičić',
#  'Junkie XL',
#  'Julian Clarke',
#  'Marvel Entertainment',
#  'Kinberg Genre',
#  'Lauren Shuler Donner',
#  'TSG Entertainment',
#  '20th Century Fox',
#  'Le Grand Rex',
#  'Variety (magazine)',
#  'Box Office Mojo',
#  'superhero film',
#  'Tim Miller (director)',
#  'Rhett Reese',
#  'Paul Wernick',
#  'Marvel Comics',
#  'Deadpool',
#  'X-Men (film series)',
#  'Ryan Reynolds',
#  'Morena Baccarin',
#  'Ed Skrein',
#  'T.J. Miller',
#  'Gina Carano',
#  'Leslie Uggams',
#  'Brianna Hildebrand',
#  'Stefan Kapičić',
#  'antihero',
#  'New Line Cinema',
#  '20th Century Fox',
#  'X-Men Origins: Wolverine',
#  'principal photography',
#  'Vancouver',
#  'IMAX',
#  'Digital Light Processing',
#  'D-Box Technologies',
#  'List of accolades received by Deadpool (film)',
#  'Golden Globe Award',
#  'Golden Globe Award for Best Motion Picture – Musical or Comedy',
#  'Golden Globe Award for Best Actor – Motion Picture Musical or Comedy',
#  'Producers Guild of America Award',
#  "Critics' Choice Movie Awards",
#  "Critics' Choice Movie Award for Best Comedy",
#  "Critics' Choice Movie Award for Best Actor in a Comedy",
#  '2016 in film',
#  '#Sequels',
#  'nonlinear narrative',
#  'Deadpool',
#  'special forces',
#  'Copycat (Marvel Comics)',
#  'Liver cancer',
#  'Lung cancer',
#  'Prostate cancer',
#  'Brain tumor',
#  'Ajax (comics)#Deadpool character',
#  'Angel Dust (comics)',
#  'healing factor',
#  'rebar',
#  'Weasel (Marvel Comics)',
#  'Blind Al',
#  'Colossus (comics)',
#  'Negasonic Teenage Warhead',
#  'X-Men',
#  'helicarrier',
#  'post-credits scene',
#  'Cable (comics)',
#  'File:Cast of Deadpool.jpg',
#  'San Diego Comic-Con',
#  'Ryan Reynolds',
#  'Deadpool',
#  'cancer',
#  'X-Men Origins: Wolverine',
#  'fourth wall',
#  'Morena Baccarin',
#  'Copycat (Marvel Comics)',
#  'damsel in distress',
#  'Ed Skrein',
#  'Ajax (comics)#Deadpool character',
#  'Weapon X',
#  'YouTube',
#  'Tim Miller (director)',
#  'T.J. Miller',
#  'Weasel (Marvel Comics)',
#  'Simon Kinberg',
#  'USA Today',
#  'Gina Carano',
#  'Angel Dust (comics)',
#  'Leslie Uggams',
#  'Blind Al',
#  'Indiewire',
#  'Brianna Hildebrand',
#  'Negasonic Teenage Warhead',
#  'X-Men',
#  'Marvel Studios',
#  'Kevin Feige',
#  'Ego the Living Planet',
#  'Guardians of the Galaxy Vol. 2',
#  'Stefan Kapičić',
#  'Colossus (comics)',
#  'Daniel Cudmore',
#  'X2 (film)',
#  'X-Men: The Last Stand',
#  'X-Men: Days of Future Past',
#  'Andre Tricoteux',
#  'Karan Soni',
#  'Jed Rees',
#  'Agent Smith',
#  'Stan Lee',
#  'Rob Liefeld',
#  'Isaac C. Singleton Jr.',
#  'Bob, Agent of Hydra',
#  'Hydra (comics)',
#  'Nathan Fillion',
#  'Twitter',
#  'Simon Kinberg',
#  'Artisan Entertainment',
#  'Marvel Entertainment',
#  'Deadpool',
#  'New Line Cinema',
#  'David S. Goyer',
#  'Ryan Reynolds',
#  'Shar Pei',
#  'Cable & Deadpool',
#  'Turnaround (filmmaking)',
#  'X-Men Origins: Wolverine',
#  'Lauren Shuler Donner',
#  'Reboot (fiction)',
#  'fourth wall',
#  'Rhett Reese',
#  'Paul Wernick',
#  'Robert Rodriguez',
#  'Tim Miller (director)',
#  'Adam Berg (director)',
#  'Blur Studio',
#  'James Cameron',
#  'David Fincher',
#  'development hell',
#  'Garrison Kane',
#  'Cannonball (comics)',
#  'Computer-generated imagery',
#  'Hillbilly',
#  'Wyre (comics)',
#  'Angel Dust (comics)',
#  'Cable (comics)',
#  'List of directorial debuts',
#  'Colossus (comics)',
#  'Simon Kinberg',
#  'The Hollywood Reporter',
#  'T. J. Miller',
#  'Ed Skrein',
#  'Gina Carano',
#  'Angel Dust (comics)',
#  'Morena Baccarin',
#  'Taylor Schilling',
#  'Crystal Reed',
#  'Rebecca Rittenhouse',
#  'Sarah Greene (actress)',
#  'Jessica De Gouw',
#  'Weasel (Marvel Comics)',
#  'Copycat (Marvel Comics)',
#  'Brianna Hildebrand',
#  'Negasonic Teenage Warhead',
#  'Ajax (comics)#Deadpool character',
#  'Leslie Uggams',
#  'Blind Al',
#  'Jed Rees',
#  'Stefan Kapičić',
#  'Colossus (comics)',
#  'Daniel Cudmore',
#  'Twitter',
#  'File:Deadpool, Georgia Viaduct, Vancouver, April 6 2015 - 3.jpg',
#  'Rolling Stone',
#  'Principal photography',
#  'Vancouver',
#  'stunt coordinator',
#  'CBC News',
#  'David Cronenberg',
#  'Eastern Promises',
#  'Yahoo! Movies',
#  'Digital Domain',
#  'Weta Digital',
#  'Rodeo FX',
#  'Luma Pictures',
#  'Image Engine',
#  'Adobe Systems',
#  'matte paintings',
#  'helicarrier',
#  'Detroit',
#  'Chicago',
#  'File:Colossus - mocap.jpg',
#  'Colossus (comics)',
#  'Computer-generated imagery',
#  'Digital Domain',
#  'Cold-formed steel',
#  'Hot working',
#  'Taxicab',
#  'Junkie XL',
#  'ARP 2600',
#  'Synclavier',
#  'Oberheim Electronics#Oberheim polyphonic synthesizers',
#  'io9',
#  'YouTube personality',
#  'Deadpool (video game)',
#  'Milan Records',
#  'Grand Rex',
#  'IMAX',
#  'Digital Light Processing',
#  'D-Box Technologies',
#  'The Hollywood Reporter',
#  'Uzbekistan',
#  'Central Board of Film Certification',
#  'The Hollywood Reporter',
#  'Hong Kong',
#  'Singapore',
#  'standing ovation',
#  'The Hollywood Reporter',
#  'Meta-joke',
#  'Business Insider',
#  'viral marketing',
#  'Christmas',
#  "Valentine's Day",
#  'io9',
#  'emoji',
#  'YouTube',
#  'Screen Junkies',
#  'The Guardian',
#  'Blu-ray',
#  '2016 in film',
#  'The Matrix Reloaded',
#  'Forbes',
#  'Variety (magazine)',
#  'X-Men: Days of Future Past',
#  'Deadline.com',
#  'James Cameron',
#  'George Lucas',
#  'Star Wars: Episode III – Revenge of the Sith',
#  'The Dark Knight Rises',
#  'The Hollywood Reporter',
#  'IMAX',
#  '3D film',
#  'Los Angeles Times',
#  'Yahoo!',
#  'Variety (magazine)',
#  'Forbes (magazine)',
#  "Presidents' Day (United States)",
#  'Zoolander 2',
#  'How to Be Single',
#  'The Hollywood Reporter',
#  'Deadline.com',
#  'Variety (magazine)',
#  'Guardians of the Galaxy (film)',
#  'Captain America: The Winter Soldier',
#  'The Hollywood Reporter',
#  'Deadline.com',
#  'R-rated',
#  'The Hangover Part II',
#  'Fifty Shades of Grey (film)',
#  'The Hollywood Reporter',
#  'Deadline.com',
#  'word of mouth',
#  'Star Wars: Episode III – Revenge of the Sith',
#  'Forbes',
#  'Century Theatres',
#  'Deadline.com',
#  'The Hollywood Reporter',
#  'The Avengers (2012 film)',
#  'The Hunger Games (film)',
#  'Forbes (magazine)',
#  'Furious 7',
#  'Alice in Wonderland (2010 film)',
#  'Wanted (2008 film)',
#  'Watchmen (film)',
#  'The Vow (2012 film)',
#  'X-Men (film)',
#  'X-Men: First Class',
#  'The Wolverine (film)',
#  'X-Men Origins: Wolverine',
#  'Deadline.com',
#  'Second weekend in box office performance',
#  'Avengers: Age of Ultron',
#  'X-Men: The Last Stand',
#  '300 (film)',
#  'Forbes',
#  'The Passion of the Christ',
#  'Forbes',
#  'Zootopia',
#  'London Has Fallen',
#  'Non-Hispanic whites',
#  'Hispanic',
#  'African-American',
#  'Asian Americans',
#  'Guardians of the Galaxy (film)',
#  'Captain America: Civil War',
#  'Avengers: Age of Ultron',
#  'Batman v Superman: Dawn of Justice',
#  'Suicide Squad (film)',
#  'The Hollywood Reporter',
#  'Spectre (2015)',
#  'United Kingdom and Ireland',
#  'Chinese New Year',
#  'Hong Kong',
#  'Singapore',
#  'The Mermaid (2016 film)',
#  'Deadline.com',
#  'Ip Man 3',
#  'Zootopia',
#  'Iron Man 3',
#  'Star Wars: The Force Awakens',
#  'Rotten Tomatoes',
#  'Rotten Tomatoes',
#  'Metacritic',
#  'CinemaScore',
#  'Peter Travers',
#  'Rolling Stone',
#  'Rolling Stone',
#  'TheWrap',
#  'Alonso Duralde',
#  'Guardians of the Galaxy (film)',
#  'Christy Lemire',
#  'Richard Roeper',
#  'Chicago Sun-Times',
#  'Kenneth Turan',
#  'Los Angeles Times',
#  'Los Angeles Times',
#  'The Hollywood Reporter',
#  'Deadline.com',
#  'Spider-Man',
#  'Superhero Hype',
#  '/Film',
#  'Domino (comics)',
#  'TheWrap',
#  'Mashable',
#  'David Leitch (filmmaker)',
#  'Rupert Sanders',
#  'Drew Goddard',
#  'Mashable',
#  'X-Force',
#  'Hugh Jackman',
#  'Twitter',
#  'Variety (magazine)',
#  'The Hollywood Reporter',
#  'British Board of Film Classification',
#  'Los Angeles Times',
#  'Variety (magazine)',
#  'MTV News',
#  'Empire (film magazine)',
#  'The Hollywood Reporter',
#  'Variety (magazine)',
#  'The Daily Dot',
#  'Bleeding Cool',
#  'The Hollywood Reporter',
#  'TheWrap',
#  'The Hollywood Reporter',
#  'Variety (magazine)',
#  'Entertainment Weekly',
#  'Deadline.com',
#  'MTV News',
#  'Deadline.com',
#  'Business Insider',
#  'The Hollywood Reporter',
#  'Twitter',
#  'Empire (magazine)',
#  'fxguide',
#  'Category:20th Century Fox films',
#  'Category:2010s action films',
#  'Category:2010s comedy films',
#  'Category:2010s superhero films',
#  'Category:2016 films',
#  'Category:American action comedy films',
#  'Category:American black comedy films',
#  'Category:American films',
#  'Category:Deadpool',
#  'Category:Directorial debut films',
#  'Category:English-language films',
#  'Category:Film scores by Junkie XL',
#  'Category:Film spin-offs',
#  'Category:Films about cancer',
#  'Category:Films about revenge',
#  'Category:Films directed by Tim Miller',
#  'Category:Films set in New York',
#  'Category:Films shot in Vancouver',
#  'Category:Films with live action and animation',
#  'Category:Human experimentation in fiction',
#  'Category:IMAX films',
#  'Category:Metafictional works',
#  'Category:Nonlinear narrative films',
#  'Category:Performance capture in film',
#  'Category:Self-reflexive films',
#  'Category:Superhero comedy films',
#  'Category:Vigilante films',
#  'Category:X-Men films']

# %%
# Show the most common link counts
link_counts = Counter()

for movie in movies:
    link_counts.update(movie[2])

link_counts.most_common(10)
# Out:
# [('Rotten Tomatoes', 9393),
#  ('Category:English-language films', 5882),
#  ('Category:American films', 5867),
#  ('Variety (magazine)', 5450),
#  ('Metacritic', 5112),
#  ('Box Office Mojo', 4186),
#  ('The New York Times', 3818),
#  ('The Hollywood Reporter', 3553),
#  ('Roger Ebert', 2707),
#  ('Los Angeles Times', 2454)]

# %%
# Prepare data for supervised machine learning task
top_links = [link for link, c in link_counts.items() if c >= 3]
print(len(top_links))
top_links[:20]

# Map link to ID number
link_to_idx = {link: idx for idx, link in enumerate(top_links)}

# Map movie to ID Number
movie_to_idx = {movie[0]: idx for idx, movie in enumerate(movies)}
movie_to_idx
# Out:
# 66913
# {'Deadpool (film)': 0,
#  'The Revenant (2015 film)': 1,
#  'Suicide Squad (film)': 2,
#  'Spectre (2015 film)': 3,
#  'Rebel Without a Cause': 4,
#  'Warcraft (film)': 5,
#  'The Martian (film)': 6,
#  'List of Marvel Cinematic Universe films': 7,
#  'X-Men (film series)': 8,
#  'The Hateful Eight': 9,
#  'The Jungle Book (2016 film)': 10,
#  'The Big Short (film)': 11,
#  '10 Cloverfield Lane': 12,
#  'Spotlight (film)': 13,
#  'Room (2015 film)': 14,
#  'Creed (film)': 15,
#  'DC Universe Animated Original Movies': 16,
#  'Star Trek Beyond': 17,
#  'Star Wars (film)': 18,
#  'Interstellar (film)': 19,
#  'Ant-Man (film)': 20,
#  'Everest (2015 film)': 21,
#  'Jurassic World': 22,
#  'Joy (film)': 23,
#  'Gods of Egypt (film)': 24,
#  'Star Wars sequel trilogy': 25,
#  'The Conjuring 2': 26,
#  'The Danish Girl (film)': 27,
#  'Sicario (2015 film)': 28,
#  'Rogue One': 29,
#  'Finding Dory': 30,
#  'Black Mass (film)': 31,
#  'Blade Runner': 32,
#  'Harry Potter (film series)': 33,
#  'Doctor Strange (film)': 34,
#  'Titanic (1997 film)': 35,
#  'Furious 7': 36,
#  'Avatar (2009 film)': 37,
#  'Ex Machina (film)': 38,
#  'Guardians of the Galaxy (film)': 39,
#  'Airlift (film)': 40,
#  'Fan (film)': 41,
#  'The Avengers (2012 film)': 42,
#  'Crimson Peak': 43,
#  'Return of the Jedi': 44,
#  'The Hunger Games (film series)': 45,
#  'The Witch (2015 film)': 46,
#  'Legend (2015 film)': 47,
#  'Fantastic Four (2015 film)': 48,
#  'Back to the Future': 49,
#  'Concussion (2015 film)': 50,
#  'London Has Fallen': 51,
#  'Divergent (film)': 52,
#  'Another Time, Another Place (1958 film)': 53,
#  'Bourne (film series)': 54,
#  'Frozen (2013 film)': 55,
#  'Pirates of the Caribbean (film series)': 56,
#  'Brooklyn (film)': 57,
#  'Hail, Caesar!': 58,
#  'The 5th Wave (film)': 59,
#  'The Man from U.N.C.L.E. (film)': 60,
#  'Man of Steel (film)': 61,
#  'Fantastic Beasts and Where to Find Them (film)': 62,
#  'The Fast and the Furious': 63,
#  '24 (2016 film)': 64,
#  'Krampus (film)': 65,
#  'Skyfall': 66,
#  'DC Extended Universe': 67,
#  'The Godfather': 68,
#  'In the Heart of the Sea (film)': 69,
#  'Carol (film)': 70,
#  'The Conjuring': 71,
#  'Me Before You (film)': 72,
#  'The Boy (2016 film)': 73,
#  'The Empire Strikes Back': 74,
#  'The Divergent Series': 75,
#  'The Dark Knight (film)': 76,
#  'Gone Girl (film)': 77,
#  'The Dark Knight Rises': 78,
#  'Wonder Woman (2017 film)': 79,
#  'The Walk (2015 film)': 80,
#  'Birdman (film)': 81,
#  'Pan (2015 film)': 82,
#  'The Matrix': 83,
#  'Saving Private Ryan': 84,
#  'Inception': 85,
#  'Tomorrowland (film)': 86,
#  'Straight Outta Compton (film)': 87,
#  'The Shawshank Redemption': 88,
#  'Fifty Shades of Grey (film)': 89,
#  'Beauty and the Beast (2017 film)': 90,
#  'The Hobbit (film series)': 91,
#  'The Legend of Tarzan (film)': 92,
#  'The Lord of the Rings (film series)': 93,
#  'Spy (2015 film)': 94,
#  'Trainwreck (film)': 95,
#  'The Shining (film)': 96,
#  'Tamasha (film)': 97,
#  'San Andreas (film)': 98,
#  'The Intern (2015 film)': 99,
#  'Inglourious Basterds': 100,
#  'Prometheus (2012 film)': 101,
#  'Django Unchained': 102,
#  'Pulp Fiction': 103,
#  'The Twilight Saga (film series)': 104,
#  'Forrest Gump': 105,
#  'Beasts of No Nation (film)': 106,
#  'Grimsby (film)': 107,
#  'Knock Knock (2015 film)': 108,
#  'Independence Day (1996 film)': 109,
#  'The Last Witch Hunter': 110,
#  'The Forest (2016 film)': 111,
#  'The Transporter Refueled': 112,
#  'The Magnificent Seven (2016 film)': 113,
#  'Casino Royale (2006 film)': 114,
#  'Whiplash (2014 film)': 115,
#  'Guardians of the Galaxy Vol. 2': 116,
#  'Hate Story 3': 117,
#  'Watchmen (film)': 118,
#  'The Lion King': 119,
#  'The Lobster': 120,
#  'Mad Max': 121,
#  'Hotel Transylvania 2': 122,
#  'Southpaw (film)': 123,
#  'Finding Nemo': 124,
#  'Sanam Teri Kasam (2016 film)': 125,
#  'Pitch Perfect 2': 126,
#  'The Jungle Book (1967 film)': 127,
#  'Jurassic Park (film)': 128,
#  'Gone with the Wind (film)': 129,
#  'Point Break (2015 film)': 130,
#  'Pixels (2015 film)': 131,
#  'Sanam Re': 132,
#  'Back to the Future Part II': 133,
#  'Citizen Kane': 134,
#  'Dirty Grandpa': 135,
#  'Justice League vs. Teen Titans': 136,
#  'The Nice Guys': 137,
#  'Hardcore Henry': 138,
#  'Trumbo (2015 film)': 139,
#  'Star Trek Into Darkness': 140,
#  'Alien (film)': 141,
#  'Housefull 3': 142,
#  'Iron Man 3': 143,
#  'Fury (2014 film)': 144,
#  'Zoolander 2': 145,
#  'Triple 9': 146,
#  'The Wizard of Oz (1939 film)': 147,
#  'Resident Evil (film series)': 148,
#  '12 Years a Slave (film)': 149,
#  'Moana (2016 film)': 150,
#  'Ip Man 3': 151,
#  'The Gift (2015 film)': 152,
#  'Pride and Prejudice and Zombies (film)': 153,
#  'Star Trek (film)': 154,
#  'Gladiator (2000 film)': 155,
#  'A Clockwork Orange (film)': 156,
#  'The Green Inferno (film)': 157,
#  'Spirited Away': 158,
#  'Apocalypse Now': 159,
#  'Jupiter Ascending': 160,
#  'Rocky': 161,
#  'Thor (film)': 162,
#  'Love (2015 film)': 163,
#  'Victor Frankenstein (film)': 164,
#  'Neerja': 165,
#  'Quantum of Solace': 166,
#  'V for Vendetta (film)': 167,
#  'The Ridiculous 6': 168,
#  'Alice in Wonderland (2010 film)': 169,
#  'The Social Network': 170,
#  '300 (film)': 171,
#  "Schindler's List": 172,
#  'Batman Begins': 173,
#  'Goodfellas': 174,
#  'The Peanuts Movie': 175,
#  'The Theory of Everything (2014 film)': 176,
#  'Great Grand Masti': 177,
#  'American Sniper': 178,
#  'Unbroken (film)': 179,
#  'Labyrinth (film)': 180,
#  'Pacific Rim (film)': 181,
#  'The Amazing Spider-Man 2': 182,
#  'Swiss Army Man': 183,
#  'Grease (film)': 184,
#  'Psycho (1960 film)': 185,
#  'Casablanca (film)': 186,
#  'Azhar (film)': 187,
#  'The Room (film)': 188,
#  'Snow White and the Huntsman': 189,
#  'Midnight Special (film)': 190,
#  'Vacation (2015 film)': 191,
#  'It Follows': 192,
#  'No Country for Old Men (film)': 193,
#  'Eddie the Eagle (film)': 194,
#  'Iron Man (2008 film)': 195,
#  "Daddy's Home (film)": 196,
#  'Lights Out (2016 film)': 197,
#  'Fight Club': 198,
#  'Underworld (film series)': 199,
#  'The Incredible Hulk (film)': 200,
#  'Welcome Back (film)': 201,
#  'The Choice (2016 film)': 202,
#  'Kyaa Kool Hain Hum 3': 203,
#  'Risen (2016 film)': 204,
#  'No Escape (2015 film)': 205,
#  'Singh Is Bliing': 206,
#  'Fitoor': 207,
#  'A Beautiful Mind (film)': 208,
#  'Olympus Has Fallen': 209,
#  'Inferno (2016 film)': 210,
#  'American Beauty (1999 film)': 211,
#  'Rocky Handsome': 212,
#  'Zoolander': 213,
#  'Transformers (film)': 214,
#  'Burnt (film)': 215,
#  'Puli (2015 film)': 216,
#  'Money Monster': 217,
#  'Transformers (film series)': 218,
#  'The Shallows (film)': 219,
#  'Jaws (film)': 220,
#  'The Dark Knight Trilogy': 221,
#  'My Big Fat Greek Wedding 2': 222,
#  'Dope (2015 film)': 223,
#  'Whiskey Tango Foxtrot (film)': 224,
#  'Jurassic Park': 225,
#  'Aladdin (1992 Disney film)': 226,
#  'Baaghi (2016 film)': 227,
#  'Purple Rain (film)': 228,
#  'The Night Before (2015 film)': 229,
#  'Knight of Cups (film)': 230,
#  'Jem and the Holograms (film)': 231,
#  'Wazir (film)': 232,
#  'Vedalam': 233,
#  'Talvar (film)': 234,
#  'Thani Oruvan': 235,
#  'Star Trek (film series)': 236,
#  'Shaandaar': 237,
#  'PK (film)': 238,
#  'Macbeth (2015 film)': 239,
#  'Black Hawk Down (film)': 240,
#  'The Magnificent Seven': 241,
#  'Miracles from Heaven (film)': 242,
#  'Snowden (film)': 243,
#  'Into the Woods (film)': 244,
#  'Gravity (film)': 245,
#  'The Girl with the Dragon Tattoo (2011 film)': 246,
#  'John Wick': 247,
#  'American Psycho (film)': 248,
#  'Zero Dark Thirty': 249,
#  'Beauty and the Beast (1991 film)': 250,
#  'American Hustle': 251,
#  'Boyhood (film)': 252,
#  'Sisters (2015 film)': 253,
#  'Passengers (2016 film)': 254,
#  'The Exorcist (film)': 255,
#  'The Neon Demon': 256,
#  'The Incredibles': 257,
#  'Keanu (film)': 258,
#  'Trainspotting (film)': 259,
#  'Braveheart': 260,
#  "Assassin's Creed (film)": 261,
#  'The Rocky Horror Picture Show': 262,
#  'Dishoom': 263,
#  'The Babadook': 264,
#  'Irudhi Suttru': 265,
#  'World War Z (film)': 266,
#  'Catch Me If You Can': 267,
#  'Top Gun': 268,
#  'The Green Mile (film)': 269,
#  'Lucy (2014 film)': 270,
#  'Rocky (film series)': 271,
#  'Dr. Strangelove': 272,
#  'Ratchet & Clank (film)': 273,
#  'Pitch Perfect': 274,
#  'The Great Gatsby (2013 film)': 275,
#  'The Boss (2016 film)': 276,
#  'The Blair Witch Project': 277,
#  'Criminal (2016 film)': 278,
#  'The Lego Movie': 279,
#  'Teenage Mutant Ninja Turtles (2014 film)': 280,
#  'The Nightmare Before Christmas': 281,
#  'Brahmotsavam (film)': 282,
#  'Toy Story': 283,
#  'The Good, the Bad and the Ugly': 284,
#  'Home Alone': 285,
#  'The Age of Adaline': 286,
#  'Black Swan (film)': 287,
#  'Youth (2015 film)': 288,
#  'The Princess Bride (film)': 289,
#  "One Flew Over the Cuckoo's Nest (film)": 290,
#  'Regression (film)': 291,
#  'Full Metal Jacket': 292,
#  'High-Rise (film)': 293,
#  'Fast & Furious 6': 294,
#  'Scarface (1983 film)': 295,
#  'American Ultra': 296,
#  "Mother's Day (2016 film)": 297,
#  'How to Be Single': 298,
#  'Aliens (film)': 299,
#  'Troy (film)': 300,
#  'Take This Lollipop': 301,
#  'Green Lantern (film)': 302,
#  'Raiders of the Lost Ark': 303,
#  'Blue Is the Warmest Colour': 304,
#  'Suffragette (film)': 305,
#  'Attack on Titan (film)': 306,
#  'Les Misérables (2012 film)': 307,
#  'Magic Mike XXL': 308,
#  'Yoga Hosers': 309,
#  'Ben-Hur (1959 film)': 310,
#  'E.T. the Extra-Terrestrial': 311,
#  'Slumdog Millionaire': 312,
#  'XXX (2002 film)': 313,
#  'Focus (2015 film)': 314,
#  'The Sound of Music (film)': 315,
#  'Eyes Wide Shut': 316,
#  'Free State of Jones (film)': 317,
#  'The Thing (1982 film)': 318,
#  'The Godfather Part II': 319,
#  'Secret in Their Eyes': 320,
#  'Charlie and the Chocolate Factory (film)': 321,
#  'Kick-Ass (film)': 322,
#  'Cloud Atlas (film)': 323,
#  'Snow White and the Seven Dwarfs (1937 film)': 324,
#  'Mike and Dave Need Wedding Dates': 325,
#  'The Man Who Knew Infinity (film)': 326,
#  'Aloha (film)': 327,
#  'Rudhramadevi (film)': 328,
#  'Brokeback Mountain': 329,
#  'Colonia (film)': 330,
#  'Ride Along 2': 331,
#  "Harry Potter and the Philosopher's Stone (film)": 332,
#  'The Help (film)': 333,
#  'Scott Pilgrim vs. the World': 334,
#  'Bone Tomahawk': 335,
#  'Trolls (film)': 336,
#  'The Pursuit of Happyness': 337,
#  'Mastizaade': 338,
#  'Into the Wild (film)': 339,
#  'Moon (film)': 340,
#  'Memento (film)': 341,
#  'Foxcatcher': 342,
#  'Kingdom of Heaven (film)': 343,
#  'Drive (2011 film)': 344,
#  'The Truman Show': 345,
#  'Entourage (film)': 346,
#  'Die Another Day': 347,
#  'Oopiri': 348,
#  'Unfriended': 349,
#  'Inside Llewyn Davis': 350,
#  'Seven (1995 film)': 351,
#  'Kung Fu Panda': 352,
#  'Iron Man 2': 353,
#  'Chappie (film)': 354,
#  'Fifty Shades of Black': 355,
#  'Donnie Darko': 356,
#  'Requiem for a Dream': 357,
#  'The Passion of the Christ': 358,
#  'We Are Your Friends (film)': 359,
#  'Eye in the Sky (2015 film)': 360,
#  'American Pie (film series)': 361,
#  'There Will Be Blood': 362,
#  'Annabelle (film)': 363,
#  'The Chronicles of Narnia (film series)': 364,
#  'Borat': 365,
#  'Fire in the Sky': 366,
#  'Sing (2016 film)': 367,
#  'Up (2009 film)': 368,
#  'The Expendables 3': 369,
#  'The Longest Ride (film)': 370,
#  'Lawrence of Arabia (film)': 371,
#  'The Amazing Spider-Man (2012 film)': 372,
#  'Pyaar Ka Punchnama 2': 373,
#  'The Cabin in the Woods': 374,
#  'The Usual Suspects': 375,
#  'The Do-Over': 376,
#  'Kill Bill': 377,
#  '2.0 (film)': 378,
#  'The Blind Side (film)': 379,
#  'Harry Potter and the Deathly Hallows – Part 2': 380,
#  'Selma (film)': 381,
#  'Shrek': 382,
#  'Tangled': 383,
#  'True Story (film)': 384,
#  '2 Girls 1 Cup': 385,
#  'The Intouchables': 386,
#  'Power Rangers (film)': 387,
#  'The 33 (film)': 388,
#  'Insidious (film)': 389,
#  'Predator (film)': 390,
#  'Nightcrawler (film)': 391,
#  'Phantom (2015 film)': 392,
#  'The Fault in Our Stars (film)': 393,
#  'The Girl on the Train (2016 film)': 394,
#  '8 Mile (film)': 395,
#  'GoldenEye': 396,
#  'Prisoners (2013 film)': 397,
#  'Ben-Hur (2016 film)': 398,
#  'The Aviator (2004 film)': 399,
#  'Eternal Sunshine of the Spotless Mind': 400,
#  'Batman (1989 film)': 401,
#  'O Brother, Where Art Thou?': 402,
#  'Green Room (film)': 403,
#  'By the Sea (2015 film)': 404,
#  'The Equalizer (film)': 405,
#  'Rocky Balboa (film)': 406,
#  'The Fifth Element': 407,
#  'The Lady in the Van': 408,
#  'Race (2016 film)': 409,
#  'Atonement (film)': 410,
#  'Scream (franchise)': 411,
#  'A Serbian Film': 412,
#  'Superman Returns': 413,
#  'The Little Prince (2015 film)': 414,
#  'Ip Man (film)': 415,
#  'Spider-Man (2002 film)': 416,
#  'Self/less': 417,
#  'Gangs of New York': 418,
#  'Drishyam (2015 film)': 419,
#  'Crash (2004 film)': 420,
#  'Spaceballs': 421,
#  'The Sixth Sense': 422,
#  'Dracula Untold': 423,
#  "It's a Wonderful Life": 424,
#  'Idiocracy': 425,
#  'The Birth of a Nation': 426,
#  'Mulholland Drive (film)': 427,
#  'Baywatch (film)': 428,
#  'Me and Earl and the Dying Girl (film)': 429,
#  'This Is the End': 430,
#  'Vertigo (film)': 431,
#  'Goodnight Mommy': 432,
#  'The Bourne Ultimatum (film)': 433,
#  'Brothers (2015 film)': 434,
#  'Noah (2014 film)': 435,
#  'Cast Away': 436,
#  'I Am Legend (film)': 437,
#  'Jazbaa': 438,
#  'Daredevil (film)': 439,
#  "Miss Peregrine's Home for Peculiar Children (film)": 440,
#  'Dead Poets Society': 441,
#  'Hero (2015 Hindi film)': 442,
#  'Point Break': 443,
#  'Silence (2016 film)': 444,
#  'The Texas Chain Saw Massacre': 445,
#  'Dallas Buyers Club': 446,
#  'Chi-Raq': 447,
#  'Minority Report (film)': 448,
#  'The Curious Case of Benjamin Button (film)': 449,
#  'Dunkirk (2017 film)': 450,
#  'Mulan (1998 film)': 451,
#  'Groundhog Day (film)': 452,
#  '12 Monkeys': 453,
#  'The Graduate': 454,
#  'Death Proof': 455,
#  'Tusk (2014 film)': 456,
#  'About Time (2013 film)': 457,
#  'Hugo (film)': 458,
#  "Breakfast at Tiffany's (film)": 459,
#  'Rustom (film)': 460,
#  'The Great Wall (film)': 461,
#  'Central Intelligence': 462,
#  'Boogie Nights': 463,
#  'Die Hard': 464,
#  'Bridesmaids (2011 film)': 465,
#  'Sucker Punch (2011 film)': 466,
#  'Hotel Transylvania': 467,
#  'Dirty Dancing': 468,
#  'Zodiac (film)': 469,
#  'Z for Zachariah (film)': 470,
#  'Willy Wonka & the Chocolate Factory': 471,
#  'Sardaar Gabbar Singh': 472,
#  'Constantine (film)': 473,
#  'Looper (film)': 474,
#  'Brave (2012 film)': 475,
#  'Hannibal (film)': 476,
#  'Jack Reacher (film)': 477,
#  'Spider-Man 3': 478,
#  'The Last Airbender': 479,
#  'Mad Max 2': 480,
#  'The Devil Wears Prada (film)': 481,
#  'Inherent Vice (film)': 482,
#  'Ennu Ninte Moideen': 483,
#  'War for the Planet of the Apes': 484,
#  'Kis Kisko Pyaar Karoon': 485,
#  'American Graffiti': 486,
#  'Movie 43': 487,
#  'True Grit (2010 film)': 488,
#  'Soylent Green': 489,
#  'Apocalypto': 490,
#  'Boyz n the Hood': 491,
#  "What's Eating Gilbert Grape": 492,
#  'Stand by Me (film)': 493,
#  'I (film)': 494,
#  'Armageddon (1998 film)': 495,
#  'Coco (2017 film)': 496,
#  'Who Framed Roger Rabbit': 497,
#  'Begin Again (film)': 498,
#  'Sherlock Holmes (2009 film)': 499,
#  'The Deer Hunter': 500,
#  'My Big Fat Greek Wedding': 501,
#  'Son of Saul': 502,
#  'Sin City (film)': 503,
#  'A Nightmare on Elm Street': 504,
#  '12 Angry Men (1957 film)': 505,
#  'Transcendence (2014 film)': 506,
#  'The Human Centipede (First Sequence)': 507,
#  'Clueless (film)': 508,
#  'Office Space': 509,
#  'Midnight in Paris': 510,
#  'Children of Men': 511,
#  'Size Zero (film)': 512,
#  'Wreck-It Ralph': 513,
#  'Batman & Robin (film)': 514,
#  'Elysium (film)': 515,
#  'Pearl Harbor (film)': 516,
#  'After Earth': 517,
#  'Hercules (2014 film)': 518,
#  'Cannibal Holocaust': 519,
#  'The Matrix (franchise)': 520,
#  'The Goonies': 521,
#  'Nerve (2016 film)': 522,
#  'WALL-E': 523,
#  'Thanga Magan (2015 film)': 524,
#  'Deliverance': 525,
#  'Paranormal Activity': 526,
#  'Ratatouille (film)': 527,
#  'Cars (film)': 528,
#  'Despicable Me': 529,
#  'Amadeus (film)': 530,
#  'Indiana Jones and the Kingdom of the Crystal Skull': 531,
#  '22 Jump Street': 532,
#  'Almost Famous': 533,
#  'American Gangster (film)': 534,
#  'The Hurt Locker': 535,
#  'Blackfish (film)': 536,
#  'Under the Skin (2013 film)': 537,
#  '28 Days Later': 538,
#  'The Godfather Part III': 539,
#  'Sinister 2': 540,
#  'The Dictator (2012 film)': 541,
#  'Zombieland': 542,
#  'Moneyball (film)': 543,
#  '2012 (film)': 544,
#  'Batman Forever': 545,
#  'Juno (film)': 546,
#  'Dazed and Confused (film)': 547,
#  'Sinister (film)': 548,
#  'Hush (2016 film)': 549,
#  'Romeo + Juliet': 550,
#  'Caligula (film)': 551,
#  'Café Society (film)': 552,
#  'Irrational Man (film)': 553,
#  'Ki & Ka': 554,
#  'The Crow (1994 film)': 555,
#  'Doctor Zhivago (film)': 556,
#  'Nannaku Prematho': 557,
#  'Hacksaw Ridge': 558,
#  'The Evil Dead': 559,
#  'Fantasia (1940 film)': 560,
#  'Saw (2004 film)': 561,
#  'The Pianist (2002 film)': 562,
#  'Metropolis (1927 film)': 563,
#  'The Butler': 564,
#  'The Little Mermaid (1989 film)': 565,
#  'Charlie (2015 Malayalam film)': 566,
#  'Heat (1995 film)': 567,
#  'Pride & Prejudice (2005 film)': 568,
#  'Do Lafzon Ki Kahani (film)': 569,
#  'Truth (2015 film)': 570,
#  'Paranormal Activity (film series)': 571,
#  'The Punisher (2004 film)': 572,
#  'Captain Phillips (film)': 573,
#  'Never Say Never Again': 574,
#  'A Nightmare on Elm Street (2010 film)': 575,
#  'The Matrix Reloaded': 576,
#  'The Visit (2015 American film)': 577,
#  'The Da Vinci Code (film)': 578,
#  'Rain Man': 579,
#  'Back to the Future Part III': 580,
#  'Our Brand Is Crisis (2015 film)': 581,
#  'King Kong (2005 film)': 582,
#  'I Am Number Four (film)': 583,
#  'Source Code': 584,
#  'Dragon Blade (film)': 585,
#  'Babel (film)': 586,
#  'The Accountant (2016 film)': 587,
#  'How to Train Your Dragon (film)': 588,
#  'Sarrainodu': 589,
#  'Batman vs. Robin': 590,
#  'Starship Troopers (film)': 591,
#  'Chef (film)': 592,
#  'Amy (2015 film)': 593,
#  'Dredd': 594,
#  'The Prince of Egypt': 595,
#  'One Night Stand (2016 film)': 596,
#  'The Giver (film)': 597,
#  'Life of Pi (film)': 598,
#  'The Bourne Supremacy (film)': 599,
#  'Rajini Murugan': 600,
#  'Superbad (film)': 601,
#  'Oldboy (2013 film)': 602,
#  'Never Let Me Go (2010 film)': 603,
#  'Mortdecai (film)': 604,
#  'Rush (2013 film)': 605,
#  'Love, Rosie (film)': 606,
#  'The Best of Me (film)': 607,
#  'The Mist (film)': 608,
#  'Dr. No (film)': 609,
#  'Kick-Ass 2 (film)': 610,
#  '21 Jump Street (film)': 611,
#  'Million Dollar Baby': 612,
#  'Terminator Salvation': 613,
#  'Halloween (1978 film)': 614,
#  '45 Years': 615,
#  'Platoon (film)': 616,
#  'Training Day': 617,
#  'War Dogs (2016 film)': 618,
#  'Predestination (film)': 619,
#  'Tinker Tailor Soldier Spy (film)': 620,
#  'Space Jam': 621,
#  'Mad Max Beyond Thunderdome': 622,
#  'The Light Between Oceans (film)': 623,
#  'Batman Returns': 624,
#  "Rosemary's Baby (film)": 625,
#  'The Human Centipede 3 (Final Sequence)': 626,
#  'The Outsiders (film)': 627,
#  'Jobs (film)': 628,
#  'District 9': 629,
#  'The Tree of Life (film)': 630,
#  'Demolition (2015 film)': 631,
#  'Rambo (film series)': 632,
#  'Riddick (film)': 633,
#  'The Patriot (2000 film)': 634,
#  'Anastasia (1997 film)': 635,
#  'Remember the Titans': 636,
#  'Taken 3': 637,
#  'The Warriors (film)': 638,
#  'Indiana Jones and the Temple of Doom': 639,
#  'Kids (film)': 640,
#  'Austin Powers (film series)': 641,
#  "She's Funny That Way": 642,
#  'Orphan (film)': 643,
#  'Nosferatu': 644,
#  'Still Alice': 645,
#  'Pawn Sacrifice': 646,
#  'Event Horizon (film)': 647,
#  "Dad's Army (2016 film)": 648,
#  '127 Hours': 649,
#  'Amélie': 650,
#  'Serenity (film)': 651,
#  'Downfall (2004 film)': 652,
#  'I Saw the Light (film)': 653,
#  "Billy Lynn's Long Halftime Walk (film)": 654,
#  'From Dusk till Dawn': 655,
#  'Jumanji': 656,
#  'Dune (film)': 657,
#  'The Duff': 658,
#  'Rise of the Planet of the Apes': 659,
#  'Sleeping with Other People': 660,
#  'Calendar Girls (2015 film)': 661,
#  'Saving Mr. Banks': 662,
#  'Pocahontas (1995 film)': 663,
#  "Pete's Dragon (2016 film)": 664,
#  'Tron': 665,
#  'Valkyrie (film)': 666,
#  'Mamma Mia! (film)': 667,
#  'Warrior (2011 film)': 668,
#  'Munich (film)': 669,
#  'Edward Scissorhands': 670,
#  'Dark Places (2015 film)': 671,
#  'Mr. Holmes': 672,
#  'Rocky IV': 673,
#  'This Is England': 674,
#  'Goldfinger (film)': 675,
#  'The Boy Next Door (film)': 676,
#  'Harry Potter and the Goblet of Fire (film)': 677,
#  "We're the Millers": 678,
#  'Te3n': 679,
#  'A.I. Artificial Intelligence': 680,
#  'Heneral Luna': 681,
#  'The Birth of a Nation (2016 film)': 682,
#  'Superman (1978 film)': 683,
#  'Deepwater Horizon (film)': 684,
#  'Lost in Translation (film)': 685,
#  'Gremlins': 686,
#  'Iraivi': 687,
#  'Stardust (2007 film)': 688,
#  'The Hangover': 689,
#  'Child 44 (film)': 690,
#  'The Perfect Guy (2015 film)': 691,
#  'Indiana Jones and the Last Crusade': 692,
#  'The Day After Tomorrow': 693,
#  'Kung Fury': 694,
#  'The Karate Kid': 695,
#  'Enemy (2013 film)': 696,
#  'Seventh Son (film)': 697,
#  'Harry Potter and the Deathly Hallows – Part 1': 698,
#  'Matilda (1996 film)': 699,
#  'Seven Samurai': 700,
#  'Get Hard': 701,
#  'Robin Hood (2010 film)': 702,
#  'The Village (2004 film)': 703,
#  '28 Weeks Later': 704,
#  'Clash of the Titans (2010 film)': 705,
#  'Visaranai': 706,
#  'Jane Got a Gun': 707,
#  "God's Not Dead (film)": 708,
#  'Dances with Wolves': 709,
#  'The World Is Not Enough': 710,
#  'Mystic River (film)': 711,
#  'American History X': 712,
#  'Airplane!': 713,
#  'Magnolia (film)': 714,
#  'Cruel Intentions': 715,
#  'Predators (film)': 716,
#  'Gran Torino': 717,
#  'Non-Stop (film)': 718,
#  'The Monkey King 2': 719,
#  'La La Land (film)': 720,
#  'Final Destination': 721,
#  'The Final Girls': 722,
#  'Nausicaä of the Valley of the Wind (film)': 723,
#  'The Secret Life of Walter Mitty (2013 film)': 724,
#  'Bad Moms': 725,
#  'Scooby-Doo (film)': 726,
#  'The Lone Ranger (2013 film)': 727,
#  'Before We Go': 728,
#  'The Boy in the Striped Pyjamas (film)': 729,
#  'Life Is Beautiful': 730,
#  'Scouts Guide to the Zombie Apocalypse': 731,
#  'Fast Five': 732,
#  'Grave of the Fireflies': 733,
#  'Ghost in the Shell (2017 film)': 734,
#  'If I Stay (film)': 735,
#  'Tomorrow Never Dies': 736,
#  "Ocean's Eleven": 737,
#  'Enthiran': 738,
#  'Anna Karenina (2012 film)': 739,
#  'Jumper (2008 film)': 740,
#  'Carrie (2013 film)': 741,
#  'Sully (film)': 742,
#  'Love & Mercy (film)': 743,
#  'Katti Batti': 744,
#  'Annie (2014 film)': 745,
#  'The Butterfly Effect': 746,
#  'Raging Bull': 747,
#  'Immortals (2011 film)': 748,
#  'Wet Hot American Summer': 749,
#  'The Stanford Prison Experiment (film)': 750,
#  'White House Down': 751,
#  'The Princess and the Frog': 752,
#  'The Last King of Scotland (film)': 753,
#  'Spartacus (film)': 754,
#  'The NeverEnding Story (film)': 755,
#  'Contagion (film)': 756,
#  'Wanted (2008 film)': 757,
#  'Don Jon': 758,
#  'The Ten Commandments (1956 film)': 759,
#  'Flight (2012 film)': 760,
#  'Highlander (film)': 761,
#  'Evil Dead (2013 film)': 762,
#  'Fruitvale Station': 763,
#  'Unforgiven': 764,
#  'A Few Good Men': 765,
#  'Blow (film)': 766,
#  'Blackhat (film)': 767,
#  'Philadelphia (film)': 768,
#  'Melancholia (2011 film)': 769,
#  'Rock the Kasbah (film)': 770,
#  'Knocked Up': 771,
#  'Rocky V': 772,
#  'First Blood': 773,
#  'Chronicle (film)': 774,
#  'Primer (film)': 775,
#  'Equals (film)': 776,
#  'The X-Files (film)': 777,
#  'Blade (film)': 778,
#  'The Matrix Revolutions': 779,
#  'Revolutionary Road (film)': 780,
#  'Men in Black (film)': 781,
#  'Salò, or the 120 Days of Sodom': 782,
#  'The Internship': 783,
#  'Spider-Man 2': 784,
#  'Jerry Maguire': 785,
#  'Norm of the North': 786,
#  'The Town (2010 film)': 787,
#  'Napoleon Dynamite': 788,
#  'Up in the Air (2009 film)': 789,
#  'The Counselor': 790,
#  'Tale of Tales (2015 film)': 791,
#  'The Judge (2014 film)': 792,
#  'The Hunchback of Notre Dame (1996 film)': 793,
#  'The Great Dictator': 794,
#  'Bangalore Days': 795,
#  "On Her Majesty's Secret Service (film)": 796,
#  'The Machinist': 797,
#  'Hot Fuzz': 798,
#  'Planet of the Apes (1968 film)': 799,
#  'Love the Coopers': 800,
#  'Maya (2015 Indian film)': 801,
#  'The Thin Red Line (1998 film)': 802,
#  'The Last of the Mohicans (1992 film)': 803,
#  'Tarzan (1999 film)': 804,
#  'Animal House': 805,
#  'Max (2015 film)': 806,
#  'The Blues Brothers (film)': 807,
#  'Moulin Rouge!': 808,
#  'Irréversible': 809,
#  'Red Dragon (film)': 810,
#  'The Aristocrats (film)': 811,
#  'Poltergeist (2015 film)': 812,
#  'The Talented Mr. Ripley (film)': 813,
#  'Brazil (1985 film)': 814,
#  'Grindhouse (film)': 815,
#  'The Addams Family (film)': 816,
#  'Bruce Lee - The Fighter': 817,
#  'The Lovely Bones (film)': 818,
#  'We Need to Talk About Kevin (film)': 819,
#  'Octopussy': 820,
#  'Grown Ups 2': 821,
#  'Blue Velvet (film)': 822,
#  'The Lazarus Effect (2015 film)': 823,
#  'The Impossible (2012 film)': 824,
#  'The Good Shepherd (film)': 825,
#  'Action Hero Biju': 826,
#  'Harry Potter and the Order of the Phoenix (film)': 827,
#  'Harry Potter and the Prisoner of Azkaban (film)': 828,
#  'The Boy and the Beast': 829,
#  'The Birds (film)': 830,
#  'The Mummy (2017 film)': 831,
#  'Ricki and the Flash': 832,
#  'Blazing Saddles': 833,
#  'The Lost Boys': 834,
#  'The SpongeBob SquarePants Movie': 835,
#  'How to Train Your Dragon 2': 836,
#  'Monty Python and the Holy Grail': 837,
#  'Friday (1995 film)': 838,
#  'Tangerine (film)': 839,
#  'Unbreakable (film)': 840,
#  'Rambo III': 841,
#  'Raman Raghav 2.0': 842,
#  'Kubo and the Two Strings': 843,
#  'School of Rock': 844,
#  'Diamonds Are Forever (film)': 845,
#  'Thelma & Louise': 846,
#  'Cell (film)': 847,
#  'The Mask (film)': 848,
#  'Cowspiracy': 849,
#  'American Reunion': 850,
#  'Elvis & Nixon': 851,
#  'Bengal Tiger (2015 film)': 852,
#  'Mr. Right (2015 film)': 853,
#  'The Girl Next Door (2004 film)': 854,
#  'Pain & Gain': 855,
#  'The Mummy Returns': 856,
#  'The Happening (2008 film)': 857,
#  'A Flying Jatt': 858,
#  'The Rock (film)': 859,
#  'Dogma (film)': 860,
#  'Dumb and Dumber To': 861,
#  'Sarbjit (film)': 862,
#  'Road House (1989 film)': 863,
#  "The Devil's Advocate (1997 film)": 864,
#  'The Water Diviner': 865,
#  'The Other Woman (2014 film)': 866,
#  'Erin Brockovich (film)': 867,
#  'Hamari Adhuri Kahani': 868,
#  'Saturday Night Fever': 869,
#  'True Romance': 870,
#  'Harry Potter and the Half-Blood Prince (film)': 871,
#  'Piku': 872,
#  'Kadhalum Kadandhu Pogum': 873,
#  'Citizenfour': 874,
#  'Big Eyes': 875,
#  'The Monuments Men': 876,
#  'Badlapur (film)': 877,
#  'West Side Story (film)': 878,
#  'Coco Chanel & Igor Stravinsky': 879,
#  'The Diary of a Teenage Girl': 880,
#  'Cape Fear (1991 film)': 881,
#  'Fifty Shades Darker (film)': 882,
#  'Solace (2015 film)': 883,
#  'Heist (2015 film)': 884,
#  'The Island (2005 film)': 885,
#  'The Wicker Man (1973 film)': 886,
#  'Silent Hill (film)': 887,
#  'Live and Let Die (film)': 888,
#  'Alien vs. Predator (film)': 889,
#  'Vanilla Sky': 890,
#  'Aranmanai 2': 891,
#  'Attack the Block': 892,
#  'Invictus (film)': 893,
#  'Coraline (film)': 894,
#  'Hairspray (2007 film)': 895,
#  '10 Endrathukulla': 896,
#  "St. Elmo's Fire (film)": 897,
#  'Waterworld': 898,
#  'Antichrist (film)': 899,
#  'Where to Invade Next': 900,
#  'Warm Bodies (film)': 901,
#  'Need for Speed (film)': 902,
#  'From Russia with Love (film)': 903,
#  'The Iron Giant': 904,
#  'Billy Elliot': 905,
#  'War Machine (film)': 906,
#  'The Untouchables (film)': 907,
#  'Licence to Kill': 908,
#  'Fantastic Four (2005 film)': 909,
#  'The Reader (2008 film)': 910,
#  'Van Helsing (film)': 911,
#  'A Very Murray Christmas': 912,
#  'Sleeping Beauty (1959 film)': 913,
#  'Mr. Nobody (film)': 914,
#  'Heathers': 915,
#  'Song of the South': 916,
#  'Happy New Year (2014 film)': 917,
#  "Kiki's Delivery Service": 918,
#  'For Your Eyes Only (film)': 919,
#  'Legends of the Fall': 920,
#  'The Great Escape (film)': 921,
#  'The Book of Eli': 922,
#  'American Idiot': 923,
#  'The Fast and the Furious (2001 film)': 924,
#  'The Descendants': 925,
#  'A View to a Kill': 926,
#  'Unity (film)': 927,
#  'The Purge (film series)': 928,
#  'Ali (film)': 929,
#  'The Karate Kid (2010 film)': 930,
#  'The Lost City of Z (film)': 931,
#  'Lolita (1962 film)': 932,
#  'Barely Lethal': 933,
#  'Insomnia (2002 film)': 934,
#  'Army of Darkness': 935,
#  'Alien 3': 936,
#  'End of Watch': 937,
#  'The Road (2009 film)': 938,
#  'Changeling (film)': 939,
#  'Shakespeare in Love': 940,
#  'What We Do in the Shadows': 941,
#  'Gandhi (film)': 942,
#  "Singin' in the Rain": 943,
#  'Dawn of the Dead (2004 film)': 944,
#  'The Infiltrator (2016 film)': 945,
#  'Butch Cassidy and the Sundance Kid': 946,
#  'Florence Foster Jenkins (film)': 947,
#  'Stonewall (2015 film)': 948,
#  'Galaxy Quest': 949,
#  'Margin Call (film)': 950,
#  'Bangalore Naatkal': 951,
#  'Barry Lyndon': 952,
#  'The Invitation (2015 film)': 953,
#  "Sophie's Choice (film)": 954,
#  'City of God (2002 film)': 955,
#  'Natural Born Killers': 956,
#  'Maggie (film)': 957,
#  'Hitman (2007 film)': 958,
#  '400 Days (film)': 959,
#  'Miruthan': 960,
#  'The Golden Compass (film)': 961,
#  "National Lampoon's Vacation": 962,
#  'Public Enemies (2009 film)': 963,
#  'Milk (film)': 964,
#  'The Blue Lagoon (1980 film)': 965,
#  'Red (2010 film)': 966,
#  'Harry Potter and the Chamber of Secrets (film)': 967,
#  'Inside Job (2010 film)': 968,
#  'Project X (2012 film)': 969,
#  'Jurassic Park III': 970,
#  '21 Grams': 971,
#  'Big Fish': 972,
#  "Jacob's Ladder (film)": 973,
#  'Lawless (film)': 974,
#  'Inside Man': 975,
#  'Main Aur Charles': 976,
#  'Legally Blonde': 977,
#  'JFK (film)': 978,
#  'Ghost (1990 film)': 979,
#  'Dum Laga Ke Haisha': 980,
#  'The Other Side of the Door (2016 film)': 981,
#  'RoboCop (2014 film)': 982,
#  'They Live': 983,
#  'The Mummy (franchise)': 984,
#  'Kaththi': 985,
#  'You Only Live Twice (film)': 986,
#  'Oculus (film)': 987,
#  'Alice in Wonderland (1951 film)': 988,
#  'Girl, Interrupted (film)': 989,
#  'Absolutely Anything': 990,
#  'In Time': 991,
#  'J. Edgar': 992,
#  'The English Patient (film)': 993,
#  'Not Another Teen Movie': 994,
#  'A Bigger Splash (film)': 995,
#  'This Is Spinal Tap': 996,
#  'Grey Gardens': 997,
#  'Hocus Pocus (1993 film)': 998,
#  "'71 (film)": 999,
#  ...}

# %%
# Given a pair (movie, link), we want the neural network to learn to predict whether this is a legitimate pair
# for each movie, we'll iterate through the wikilinks on the movie page and record the movie title and each link as a tuple. 
# The final pairs list will consist of tuples of every (movie, link) pairing on all of Wikipedia.
# Create a blank array
pairs = []

for movie in movies:
    pairs.extend((link_to_idx[link], movie_to_idx[movie[0]]) for link in movie[2] if link in link_to_idx)

pairs_set = set(pairs)
len(pairs), len(top_links), len(movie_to_idx)
pairs_set
# Out:
# {(2454, 7796),
#  (21670, 416),
#  (2926, 6061),
#  (4849, 255),
#  (35937, 8392),
#  (23746, 1366),
#  (18849, 2311),
#  (13688, 7765),
#  (19206, 2373),
#  (178, 2893),
#  (11820, 8449),
#  (42710, 5809),
#  (965, 7725),
#  (22, 1106),
#  (1203, 8556),
#  (33113, 1909),
#  (43079, 8950),
#  (321, 5887),
#  (61712, 5361),
#  (15937, 216),
#  (1931, 369),
#  (43991, 3682),
#  (2988, 836),
#  (402, 211),
#  (13348, 3766),
#  (23548, 3035),
#  (433, 5722),
#  (7609, 5065),
#  (700, 4275),
#  (22, 4515),
#  (2966, 2139),
#  (27551, 570),
#  (943, 65),
#  (22, 8142),
#  (19893, 2249),
#  (22873, 7291),
#  (16570, 2666),
#  (22698, 4247),
#  (9868, 8215),
#  (22, 9301),
#  (24719, 4337),
#  (56790, 4089),
#  (24937, 481),
#  (862, 6414),
#  (55409, 3392),
#  (51124, 6238),
#  (4588, 6739),
#  (25841, 2840),
#  (1591, 3611),
#  (11202, 2683),
#  (66068, 8593),
#  (60643, 5100),
#  (10865, 5926),
#  (690, 66),
#  (53488, 9161),
#  (35748, 996),
#  (18468, 7543),
#  (215, 2246),
#  (7534, 6429),
#  (19506, 310),
#  (57410, 7048),
#  (7381, 1666),
#  (8904, 1043),
#  (37124, 8908),
#  (22144, 389),
#  (31043, 1277),
#  (4642, 2798),
#  (7175, 552),
#  (40707, 4603),
#  (15154, 2666),
#  (43153, 3346),
#  (740, 4201),
#  (15726, 3398),
#  (50139, 2826),
#  (14713, 2331),
#  (568, 1282),
#  (5792, 1023),
#  (21, 408),
#  (5727, 737),
#  (7011, 7138),
#  (25644, 5435),
#  (36098, 3218),
#  (6343, 7994),
#  (3266, 20),
#  (6768, 60),
#  (1581, 1563),
#  (205, 28),
#  (28147, 6041),
#  (10955, 1747),
#  (1302, 739),
#  (205, 3969),
#  (236, 2830),
#  (25086, 2830),
#  (37390, 4423),
#  (504, 4058),
#  (3922, 1338),
#  (205, 5414),
#  (15964, 6287),
#  (4160, 1509),
#  (13305, 1934),
#  (5720, 4311),
#  (1068, 2448),
#  (1693, 3971),
#  (10542, 596),
#  (41454, 1428),
#  (13991, 6429),
#  (54432, 3197),
#  (10492, 7904),
#  (3922, 4001),
#  (205, 4939),
#  (1593, 3563),
#  (1068, 2043),
#  (37524, 8299),
#  (39938, 4746),
#  (11558, 131),
#  (2803, 1420),
#  (164, 664),
#  (24544, 1726),
#  (1696, 6806),
#  (367, 5908),
#  (57055, 8398),
#  (18188, 275),
#  (5779, 2437),
#  (45072, 3897),
#  (30889, 4066),
#  (27657, 8853),
#  (32080, 2312),
#  (8981, 93),
#  ...}

# %% [markdown]
# #Build Neural Network & Train Model

# %%
def movie_embedding_model(embedding_size=50):
    link = Input(name='link', shape=(1,))
    movie = Input(name='movie', shape=(1,))
    link_embedding = Embedding(name='link_embedding', 
                               input_dim=len(top_links), 
                               output_dim=embedding_size)(link)
    movie_embedding = Embedding(name='movie_embedding', 
                                input_dim=len(movie_to_idx), 
                                output_dim=embedding_size)(movie)
    dot = Dot(name='dot_product', normalize=True, axes=2)([link_embedding, movie_embedding])
    merged = Reshape((1,))(dot)
    model = Model(inputs=[link, movie], outputs=[merged])
    model.compile(optimizer='nadam', loss='mse')
    return model

model = movie_embedding_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  link (InputLayer)              [(None, 1)]          0           []
#
#  movie (InputLayer)             [(None, 1)]          0           []
#
#  link_embedding (Embedding)     (None, 1, 50)        3345650     ['link[0][0]']
#
#  movie_embedding (Embedding)    (None, 1, 50)        500000      ['movie[0][0]']
#
#  dot_product (Dot)              (None, 1, 1)         0           ['link_embedding[0][0]',
#                                                                   'movie_embedding[0][0]']
#
#  reshape (Reshape)              (None, 1)            0           ['dot_product[0][0]']
#
# ==================================================================================================
# Total params: 3,845,650
# Trainable params: 3,845,650
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
random.seed(5)

def batchifier(pairs, positive_samples=50, negative_ratio=10):
    batch_size = positive_samples * (1 + negative_ratio)
    batch = np.zeros((batch_size, 3))
    while True:
        for idx, (link_id, movie_id) in enumerate(random.sample(pairs, positive_samples)):
            batch[idx, :] = (link_id, movie_id, 1)
        idx = positive_samples
        while idx < batch_size:
            movie_id = random.randrange(len(movie_to_idx))
            link_id = random.randrange(len(top_links))
            if not (link_id, movie_id) in pairs_set:
                batch[idx, :] = (link_id, movie_id, -1)
                idx += 1
        np.random.shuffle(batch)
        yield {'link': batch[:, 0], 'movie': batch[:, 1]}, batch[:, 2]

next(batchifier(pairs, positive_samples=3, negative_ratio=2))
# Out:
# ({'link': array([20558., 31254., 32318., 22418.,  3801.,  1313., 32643., 48731.,
#          13365.]),
#   'movie': array([ 849., 5530., 7685., 1529., 5874., 7236., 7628., 1854., 6238.])},
#  array([-1.,  1., -1.,  1., -1.,  1., -1., -1., -1.]))

# %%
# Train Model
positive_samples_per_batch = 512

model.fit_generator(
    batchifier(pairs, positive_samples=positive_samples_per_batch, negative_ratio=10),
    epochs=5,
    steps_per_epoch=len(pairs) // positive_samples_per_batch,
    verbose=1
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 1854/1854 [==============================] - 53s 27ms/step - loss: 0.5228
# Epoch 2/5
# 1854/1854 [==============================] - 51s 27ms/step - loss: 0.2323
# Epoch 3/5
# 1854/1854 [==============================] - 54s 29ms/step - loss: 0.2216
# Epoch 4/5
# 1854/1854 [==============================] - 50s 27ms/step - loss: 0.2179
# Epoch 5/5
# 1854/1854 [==============================] - 51s 27ms/step - loss: 0.2158

# %%
# Save our model
model.save('movie_embeddings.h5')

# %% [markdown]
# # Find Most Similar Movies
#
# #### Now that we have the embeddings, we can use them to recommend movies that our model has learned are most similar to a given movie.
# <br>
#
#
# The function below takes in either a movie or a link, a set of embeddings, and returns the `n` most similar items to the query. It does this by computing the dot product between the query and embeddings. Because we normalized the embeddings, the dot product represents the [cosine similarity](http://blog.christianperone.com/2013/09/machine-learning-cosine-similarity-for-vector-space-models-part-iii/) between two vectors.
# <div>
# <img src="https://assets.datacamp.com/production/repositories/4375/datasets/c71ee9689f2a54b5273988240e8f198c8ff71f32/cosine_sim.png" width="400"/>
# </div>
#
# Once we have the dot products, we can sort the results to find the closest entities in the embedding space. With cosine similarity, higher numbers indicate entities that are closer together, with -1 the furthest apart and +1 closest together.

# %%
# Get the Movie embeddings layers 
movie = model.get_layer('movie_embedding')

# Get the weights 
movie_weights = movie.get_weights()[0]

# Get the matrix normal of movie_weights 
movie_lengths = np.linalg.norm(movie_weights, axis=1)

# Get the normalized movie embeddigns 
normalized_movies = (movie_weights.T / movie_lengths).T

def similar_movies(movie, normalized_movies):
    
    # This represents the cosine similarity of the two vectors
    dists = np.dot(normalized_movies, normalized_movies[movie_to_idx[movie]])

    # Sort dot product results to get the most similar movies
    closest = np.argsort(dists)[-10:]
    for c in reversed(closest):
        print(c, movies[c][0], dists[c])

similar_movies("Interstellar (film)", normalized_movies)
# Out:
# 19 Interstellar (film) 0.9999999
# 85 Inception 0.9825766
# 101 Prometheus (2012 film) 0.9711494
# 6 The Martian (film) 0.9691768
# 181 Pacific Rim (film) 0.9676412
# 22 Jurassic World 0.96634257
# 784 Spider-Man 2 0.9628183
# 37 Avatar (2009 film) 0.96267784
# 182 The Amazing Spider-Man 2 0.9584531
# 29 Rogue One 0.95834017

# %%
similar_movies("Titanic (1997 film)", normalized_movies)
# Out:
# 35 Titanic (1997 film) 1.0000001
# 84 Saving Private Ryan 0.942979
# 85 Inception 0.9202326
# 972 Big Fish 0.91959006
# 303 Raiders of the Lost Ark 0.9158712
# 1085 Planet of the Apes (2001 film) 0.9144706
# 321 Charlie and the Chocolate Factory (film) 0.9129013
# 531 Indiana Jones and the Kingdom of the Crystal Skull 0.90984404
# 245 Gravity (film) 0.9077564
# 155 Gladiator (2000 film) 0.90726584

# %% [markdown]
# # Find Most Similar Wikipedia links
# We also have the embeddings of wikipedia links (which are themselves Wikipedia pages). We can take a similar approach to extract these and find the most similar to a query page.

# %%
link = model.get_layer('link_embedding')
link_weights = link.get_weights()[0]
link_lengths = np.linalg.norm(link_weights, axis=1)
normalized_links = (link_weights.T / link_lengths).T

def similar_links(link):
    dists = np.dot(normalized_links, normalized_links[link_to_idx[link]])
    closest = np.argsort(dists)[-10:]
    for c in reversed(closest):
        print(c, top_links[c], dists[c])

similar_links('George Lucas')
# Out:
# 127 George Lucas 1.0
# 3176 Star Wars (film) 0.96305823
# 3696 Raiders of the Lost Ark 0.95845854
# 2778 Lucasfilm 0.94576746
# 2919 Close Encounters of the Third Kind 0.9295887
# 8301 Academy Award for Visual Effects 0.9214847
# 2884 London Symphony Orchestra 0.9202094
# 976 Hugo Award for Best Dramatic Presentation 0.91857505
# 2810 film treatment 0.9152058
# 2984 Saturn Award for Best Science Fiction Film 0.9124589
